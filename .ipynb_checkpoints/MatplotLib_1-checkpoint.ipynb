# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x=range(100)
y=[val**2 for val in x]
plt.plot(x,y)

# %%
# Using Numpy
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)
plt.plot(x,y)

# %%
x=np.linspace(-3,2,50)
y=x ** 2 - 2 * x + 1.
plt.plot(x,y)

# %%
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)
z=np.cos(x)
plt.plot(x,y)
plt.plot(x,z)
plt.show()
# Matplot lib picks different colors for different plot.

# %%
data=np.loadtxt('numpy.txt')
plt.plot(data[:,0],data[:,1])

# %%
# Scatter Plots and Bar Graphs

# %%
sct=np.random.randn(20,2)
print(sct)
plt.scatter(sct[:,0],sct[:,1])
# Out:
# [[-0.14375685 -0.91932007]
#  [ 0.67911409 -1.40950497]
#  [ 0.23755822 -1.85008736]
#  [ 0.83503379  1.13514342]
#  [ 0.24351194  0.75752583]
#  [-0.03914706 -0.11569739]
#  [ 0.4131263  -0.87896246]
#  [-0.89735016  0.44305296]
#  [-0.38391121 -0.33490079]
#  [-0.5775126  -0.25689489]
#  [ 0.21648485  0.68373213]
#  [-0.58814859 -0.73868541]
#  [-0.96696029 -0.31855922]
#  [ 1.24351462 -1.39523077]
#  [ 0.51590239 -0.66461552]
#  [ 0.0042921  -0.48879186]
#  [ 1.33454696 -0.35414701]
#  [-0.07420111 -1.8406542 ]
#  [ 0.35072013 -1.42538729]
#  [-1.21410268  0.80501082]]

# %%
ghj =[5, 10 ,15, 20, 25]
it =[ 1, 2, 3, 4, 5]
plt.bar(ghj,it) # simple bar plot
# Out:
# <Container object of 5 artists>

# %%
plt.bar(ghj,it,width=5) # you can change the thickness of a bar, by default the bar will have a thickness of 0.8 units
# Out:
# <Container object of 5 artists>

# %%
plt.barh(ghj,it) # barh is a horizontal bar graph
# Out:
# <Container object of 5 artists>

# %%
import numpy as np
new_list = [[5., 25., 50., 20.], [4., 23., 51., 17.], [6., 22., 52., 19.]]
x=np.arange(4)
plt.bar(x+0.00,new_list[0],color='b',width=0.25)
plt.bar(x+0.25,new_list[1],color='r',width=0.25)
plt.bar(x+0.50,new_list[2],color='g',width=0.25)
# Out:
# <Container object of 4 artists>

# %%
#Stacked Bar charts
p = [5., 30., 45., 22.]
q = [5., 25., 50., 20.]
x =range(4)
plt.bar(x, p, color ='b')
plt.bar(x, q, color ='y',bottom=p)
# Out:
# <Container object of 4 artists>

# %%
# plotting more than 2 values
A = np.array([5., 30., 45., 22.])
B = np.array([5., 25., 50., 20.])
C = np.array([1., 2., 1., 1.])
X = np.arange(4)
plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'g', bottom = A)
plt.bar(X, C, color = 'r', bottom = A + B) # for the third argument, I use A+B
plt.show()

# %%
black_money = np.array([5., 30., 45., 22.]) 
white_money = np.array([5., 25., 50., 20.])
z = np.arange(4)
plt.barh(z, -black_money, color ='g')
plt.barh(z, white_money, color ='r')
# Out:
# <Container object of 4 artists>

# %%
#Pie charts
y=[5,10,25,65]
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x10e5ad198>,
#   <matplotlib.patches.Wedge at 0x10e5ade10>,
#   <matplotlib.patches.Wedge at 0x10e5b4a90>,
#   <matplotlib.patches.Wedge at 0x10e5bb710>],
#  [<matplotlib.text.Text at 0x10e5ad9b0>,
#   <matplotlib.text.Text at 0x10e5b4630>,
#   <matplotlib.text.Text at 0x10e5bb2b0>,
#   <matplotlib.text.Text at 0x10e5bbef0>])

# %%
#Histograms
d=np.random.randn(100)
plt.hist(d,bins=20)
# Out:
# (array([  1.,   0.,   1.,   0.,   4.,   2.,   4.,   6.,   4.,   7.,   9.,
#          13.,   5.,  13.,   8.,   5.,   4.,   6.,   4.,   4.]),
#  array([-2.70337425, -2.45990011, -2.21642596, -1.97295182, -1.72947768,
#         -1.48600354, -1.2425294 , -0.99905526, -0.75558112, -0.51210698,
#         -0.26863284, -0.0251587 ,  0.21831544,  0.46178958,  0.70526372,
#          0.94873786,  1.192212  ,  1.43568614,  1.67916028,  1.92263442,
#          2.16610856]),
#  <a list of 20 Patch objects>)

# %%
d=np.random.randn(100)
plt.boxplot(d)
#1) The red bar is the median of the distribution
#2) The blue box includes 50 percent of the data from the lower quartile to the upper quartile. 
#   Thus, the box is centered on the median of the data.
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10e0f47b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x10e3ea6a0>,
#   <matplotlib.lines.Line2D at 0x10e3ea0f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10d97d978>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10e423128>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10e1cddd8>,
#   <matplotlib.lines.Line2D at 0x10e1e5ba8>]}

# %%
d=np.random.randn(100,5)
plt.boxplot(d)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10d5dcc50>,
#   <matplotlib.lines.Line2D at 0x10d5d19e8>,
#   <matplotlib.lines.Line2D at 0x10d6c5be0>,
#   <matplotlib.lines.Line2D at 0x10d6acb70>,
#   <matplotlib.lines.Line2D at 0x10ea164e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x10d6fbf60>,
#   <matplotlib.lines.Line2D at 0x10d02ce10>,
#   <matplotlib.lines.Line2D at 0x10cfb8e10>,
#   <matplotlib.lines.Line2D at 0x10cfd2a58>,
#   <matplotlib.lines.Line2D at 0x10e3bb128>,
#   <matplotlib.lines.Line2D at 0x10d5d3d30>,
#   <matplotlib.lines.Line2D at 0x10d6a9b38>,
#   <matplotlib.lines.Line2D at 0x10d6a9cc0>,
#   <matplotlib.lines.Line2D at 0x10ea1bdd8>,
#   <matplotlib.lines.Line2D at 0x10ea21cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10d5d1198>,
#   <matplotlib.lines.Line2D at 0x10d6c55f8>,
#   <matplotlib.lines.Line2D at 0x10d6aca90>,
#   <matplotlib.lines.Line2D at 0x10ea11d30>,
#   <matplotlib.lines.Line2D at 0x10ea27d30>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10d6aae10>,
#   <matplotlib.lines.Line2D at 0x10cfcfcc0>,
#   <matplotlib.lines.Line2D at 0x10ea04908>,
#   <matplotlib.lines.Line2D at 0x10ea11518>,
#   <matplotlib.lines.Line2D at 0x10ea21e48>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10d5dc710>,
#   <matplotlib.lines.Line2D at 0x10cfd7be0>,
#   <matplotlib.lines.Line2D at 0x10ab525f8>,
#   <matplotlib.lines.Line2D at 0x10498d4a8>,
#   <matplotlib.lines.Line2D at 0x1048451d0>,
#   <matplotlib.lines.Line2D at 0x10e3bbfd0>,
#   <matplotlib.lines.Line2D at 0x10d6b6ac8>,
#   <matplotlib.lines.Line2D at 0x10d6b6c50>,
#   <matplotlib.lines.Line2D at 0x10ea16d68>,
#   <matplotlib.lines.Line2D at 0x10ea1bc50>]}
